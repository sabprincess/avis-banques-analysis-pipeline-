# %%
import googlemaps
import requests
import pandas as pd

API_KEY = "AIzaSyACo0eRv5pDIiaJ7pe1_W7qkVg8A4I_yTM"  

gmaps = googlemaps.Client(key=API_KEY)

def search_banks(query, location=None, radius=None):
    """Recherche des agences bancaires."""
    params = {
        'query': query,
        'key': API_KEY
    }
    if location:
        params['location'] = location
        params['radius'] = radius
    
    response = requests.get("https://maps.googleapis.com/maps/api/place/textsearch/json", params=params)
    results = response.json().get('results', [])
    return results


def get_place_details(place_id):
    """Récupère les détails d'un lieu, y compris les avis."""
    place_details = gmaps.place(place_id, fields=['reviews', 'name'])
    return place_details.get('result')


# Exemple d'utilisation
bank_results = search_banks("agences bancaires à Casablanca")

all_reviews = []
for bank in bank_results:
    place_id = bank['place_id']
    details = get_place_details(place_id)
    if details and 'reviews' in details:
        reviews = details['reviews']
        for review in reviews:
            all_reviews.append({
                'bank_name': details['name'],
                'author': review['author_name'],
                'rating': review['rating'],
                'text': review['text'],
                'time': review['time']
            })

# Afficher les avis (ou les sauvegarder dans un fichier)
print(all_reviews)

# Convertir en DataFrame Pandas (facultatif)
df = pd.DataFrame(all_reviews)
print(df)

#df.to_csv('avis_agences_bancaires.csv', encoding='utf-8')
# Out:
# []
# Empty DataFrame
# Columns: []
# Index: []

# %%
import googlemaps
import requests
import pandas as pd

# Remplacez par votre clé API
API_KEY = "AIzaSyACo0eRv5pDIiaJ7pe1_W7qkVg8A4I_yTM"

gmaps = googlemaps.Client(key=API_KEY)

def search_banks(query, location=None, radius=None):
    """Recherche des agences bancaires."""
    params = {
        'query': query,
        'key': API_KEY
    }
    if location:
        params['location'] = location
        params['radius'] = radius
    
    response = requests.get("https://maps.googleapis.com/maps/api/place/textsearch/json", params=params)
    results = response.json().get('results', [])
    return results


def get_place_details(place_id):
    """Récupère les détails d'un lieu, y compris les avis."""
    try:
        place_details = gmaps.place(place_id, fields=['reviews', 'name'])
        return place_details.get('result')
    except Exception as e:
        print(f"Erreur lors de la récupération des détails du lieu : {e}")
        return None


# Exemple d'utilisation : Recherche d'agences BMCE à Casablanca
# Coordonnées de Casablanca (approximatives)
casablanca_location = "-33.5731104, -7.5898434"
search_query = "BMCE à Casablanca"  # Recherche plus précise

bank_results = search_banks(search_query, location=casablanca_location, radius=5000)  # Rayon de 5km

# Ajout de débogage pour afficher les résultats de la recherche
print("Résultats de la recherche d'agences BMCE:", bank_results)

all_reviews = []
for bank in bank_results:
    place_id = bank['place_id']
    details = get_place_details(place_id)

    # Ajout de débogage pour afficher les détails du lieu
    print("Détails du lieu:", details)

    if details and 'reviews' in details:
        reviews = details['reviews']
        for review in reviews:
            all_reviews.append({
                'bank_name': details['name'],
                'author': review['author_name'],
                'rating': review['rating'],
                'text': review['text'],
                'time': review['time']
            })

# Afficher les avis (ou les sauvegarder dans un fichier)
print("Tous les avis:", all_reviews)

# Convertir en DataFrame Pandas (facultatif)
df = pd.DataFrame(all_reviews)
print(df)

#df.to_csv('avis_agences_bancaires.csv', encoding='utf-8')
# Out:
# {
#     "error_message": "This API project is not authorized to use this API.",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Failed to restart the Kernel.
#
# request to http://127.0.0.1:8788/api/kernels/d26be791-f5bf-47d6-a1fd-6ca41d56e4ae/restart?1742336945240 failed, reason: connect ECONNREFUSED 127.0.0.1:8788.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 7
#       4 response = requests.get(url)
#       5 data = response.json()
# ----> 7 for review in data['result']['reviews']:
#       8     print(f"Auteur : {review['author_name']}, Note : {review['rating']}, Avis : {review['text']}")
#
# KeyError: 'result'
