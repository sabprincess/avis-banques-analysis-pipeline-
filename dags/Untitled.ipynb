# %%
import pandas as pd
from sqlalchemy import create_engine

# Connexion PostgreSQL
engine = create_engine("postgresql://postgres:motdepasse@localhost:5432/banques_maroc")

# Lire la table
df = pd.read_sql("SELECT * FROM fact_reviews", engine)

# Export CSV bien formaté
df.to_csv("/mnt/c/Users/Sabri/Downloads/factt_reviews_clean.csv", index=False,encoding="utf-8",sep=",",
    quotechar='"',
    quoting=csv.QUOTE_ALL,
    line_terminator="\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       8 df = pd.read_sql("SELECT * FROM fact_reviews", engine)
#      10 # Export CSV bien formaté
#      11 df.to_csv("/mnt/c/Users/Sabri/Downloads/factt_reviews_clean.csv", index=False,encoding="utf-8",sep=",",
#      12     quotechar='"',
# ---> 13     quoting=csv.QUOTE_ALL,
#      14     line_terminator="\n")
#
# NameError: name 'csv' is not defined
